# %% [markdown]
# # Week 2 exercises

# %% [markdown]
# ## Comprehension checks
#
# Usual deal - make sure you know why these do what they do (even if it's to throw an error)

# %%
def print_with_exclamations(message):
    print(message + "!!!")

# %%
print_with_exclamations_again("Hello")

def print_with_exclamations_again(message):
    print(message + "!!!")

# %%
def print_with_exclamations(message):
print(message + "!!!")

print_with_exclamations("Hello")

# %%
def print_with_exclamations(message):
    print(message + "!!!")

print_with_exclamations("Hello")

# %%
def print_with_exclamations(message):
    print(message + "!!!")

print_with_exclamations()

# %%
x = print("Hi")
print(x)

# %%
def add_exclamation(message):
    new_message = message + "!"
return message

loud = add_exclamation("Hello")
print(loud)

# %%
def add_exclamation(message):
    return message
    print("!")
    
loud = add_exclamation("Hello")
print(loud)

# %%
def add_exclamation(message):
    new_message = message + "!"
    return message

loud = add_exclamation("Hello")
print(loud)

# %%
def add_exclamation(message):
    new_message = message + "!"
    return new_message

loud = add_exclamation("Hello")
print(loud)

# %%
def add_exclamation(message):
    new_message = message + "!"
    return new_message

loud = add_exclamation("Hello")
print(new_message)

# %%
message = "Hello"

def add_exclamation(message):
    message = message + "!"
    return message

loud = add_exclamation(message)
print(message, loud)

# %%
def double_and_triple(x):
    return 2*x, 3*x

a = double_and_triple(3)
print(a)

# %%
from math import pi 

def degrees_to_radians(angle, decimal_places):
    return round(angle * pi / 180, decimal_places)

print(degrees_to_radians(90))

# %%
from math import pi 

def degrees_to_radians(angle, decimal_places=3):
    return round(angle * pi / 180, decimal_places)

print(degrees_to_radians(90))

# %%
def subtract(a, b):
    return a-b 

print(subtract(2, 10))

# %%
def subtract(a, b):
    return a-b 

print(subtract(b=2, 10))

# %%
def subtract(a, b):
    return a-b 

print(subtract(10, b=2))

# %%
def subtract(a, b):
    return a-b 

print(subtract(b=2, a=10))

# %%
def doc_string_function():
    'Here is a docstring for a function with no body -- will we get an error?'

doc_string_function()

# %%
def quadruple_me(x):
    a = 4 * x
    return a

a = 3
b = quadruple_me(2)
print(a, b)

# %% [markdown]
# ## Exercise 1

# %% [markdown]
# Here's a function I have written to take the average of two numbers.  It's also written into your answer template.  Use the function to find the average of 19,315 and 22,664.

# %%
def average(m,n):
    return 0.5*(m+n)

# %% [markdown]
# ### A)
#
# Now let's make `average` do some real work. Our robot's centre point lies exactly halfway between its two wheels.
#
# Suppose the left wheel is at position (40, 60) mm and the right wheel is at (100, 140) mm. Use the `average` function to compute the coordinates of the robot's centre point, and print the result.
#
# ### B)
#
#
# **Discussion (with your partner):**
#
# if you had *four* numbers, would `average(average(a, b), average(c, d))` give the same answer as adding all four and dividing by 4? Would it still work for *three* numbers, i.e. `average(average(a, b), c)`? Try it -- and remember what week 1 taught you about comparing floats with `==`.

# %% [markdown]
# ## Exercise 2

# %% [markdown]
# In week 1, you wrote code to test whether a point at (x, y) lies within radius R of a point (u, v), using only arithmetic and comparison operators (no square root!).
#
# That was useful code -- but to reuse it for a different obstacle, you had to copy, paste and edit it. This week we can do better: package it as a function.
#
# ### A)
#
# Write a function `is_colliding(x, y, u, v, R)` that returns `True` if the point (x, y) lies within radius R of the point (u, v), and `False` otherwise. Include a docstring. You should not need the square root function -- reuse your week 1 approach.
#
# Test it against the same two cases as last week -- your function should make this almost effortless now:
#
# + Robot centred at (0, 0) with radius 82.5 mm, obstacle at (50, 60) mm. Expected output: `True`
# + Robot centred at (0, 0) with radius 82.5 mm, obstacle at (70, 60) mm. Expected output: `False`
#
# ### B)
#
# In week 1 we mentioned the more general case: two *circles* have collided if the distance between their centres is less than the sum of their radii. Write a second function that returns a boolean for this case. Do you need to change the number of inputs / outputs for this function?
#
# Test cases (robot at (0, 0) with radius 82.5 mm):
#
# + Obstacle circle centred at (100, 50) mm with radius 40 mm. Expected output: `True`
# + Obstacle circle centred at (100, 50) mm with radius 20 mm. Expected output: `False`

# %% [markdown]
# ## Exercise 3 - Robot Wheel Kinematics

# %% [markdown]
# Our robot moves by spinning its two wheels independently -- this is called a *differential drive*. Here's the small amount of theory you need:
#
# + A wheel of radius $r$ spinning at angular speed $\omega$ (in radians per second) drives the robot forward at speed $v = r\omega$ at that wheel.
# + When both wheels spin at the same speed, the robot drives in a straight line. When they differ, it turns.
# + The robot's overall **forward speed** is the *average* of its two wheel speeds.
# + The robot's **turn rate** (radians per second) is $(v_{right} - v_{left}) / W$, where $W$ is the wheel separation.
#
# Recall from week 1 (robot.py) that our robot's wheels have radius 35.0 mm and are separated by 150.0 mm. In the same file, add functions for calculating wheel speed, robot speed and robot motion.
#
# ### Part 1
#
# Write a function `wheel_speed(omega, radius)` that returns the linear speed of a wheel, with a docstring. If radius is in mm, what units will the speed be in?
#
# ### Part 2
#
# Write a function `robot_speed(omega_left, omega_right, radius)` that returns the robot's forward speed. It should *call* `wheel_speed` -- and the `average` function from Exercise 1.
#
# ### Part 3
#
# Write a function `robot_motion(omega_left, omega_right, radius, separation)` that returns **two** values: the forward speed and the turn rate.
#
# ### Sanity checks
#
# Test your functions on cases where you already know the physical answer:
#
# + Both wheels at 2.0 rad/s: forward speed 70.0 mm/s, turn rate 0 (straight line).
# + Left wheel at -2.0 rad/s, right wheel at +2.0 rad/s: forward speed 0 (the robot spins on the spot). What is the turn rate?

# %% [markdown]
# ## Exercise 4

# %% [markdown]
# Complex numbers, of the form $z = a+ib$, where $i=\sqrt(=1)$ are used throughout mathematics and engineering. In Python, we can represent a complex number with two variables -- one for storing the real part (a) and one for storing the imaginary part (b). Let's write some functions for processing complex numbers.
#
#
# 1. Write `complex_sum(a, b, c, d)` which returns **two** values: the real and imaginary parts of $z_3 = z_1 + z_2 = (a + bi) + (c + di)$.
# 2. Write `complex_product(a, b, c, d)` which returns the real and imaginary parts of $ z_3 = z_1 * z_2 = (a + bi)(c + di) = (ac - bd) + (ad+ bc)i$.
# 3. Write `modulus_squared(a, b)` which returns $a^2 + b^2$.
# 4. Using **only calls to your functions**, verify the identity $|z_1 * z_2|^2 = |z_1|^2 * |z_2|^2$ for $z_1 = 1.1 + 2.3i$ and $z_2 = 0.7 + 1.9i$. Your verification should be a single boolean expression -- and remember from week 1 that comparing floats with `==` is risky. Check the difference is less than $10^{-5}$ instead.

# %% [markdown]
# ## Exercise 5 - Numerical equation solving.

# %% [markdown]
# **This one is a stretch exercise -- only attempt it once you've finished the others.** As with other stretch exercises, this is intended for those who have previous experience of programming. You may you any Python syntax, including syntax we have not yet covered in this course.
#
# Find the solution of the equation below numerically.
#
# $ 10e^{\frac{x}{10}} + x - 17 = 0$
#
# Suggested approach:
#  - Implement the left-hand side of the expression above as a function, `f(x)`
#  - You'll need `from math import exp` before you can use the exponential function
#  - Write a function to find the lowest integer $x$ such that the solution is in the interval $x$ and $x+1$
#  - Write a function that reduces the interval further using a bisection search, i.e. halving it at every step. Stop when the interval is narrower than $10^{-5}$ (sound familiar?)
#
# **Hint:** at each step, you need to decide which half of the interval contains the solution. Think about the *sign* of $f(x)$ at each end of the interval, and at the midpoint. If the sign changes between two points, the solution lies between them.
