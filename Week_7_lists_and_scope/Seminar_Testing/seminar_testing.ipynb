# %% [markdown]
# # Seminar 4 - Testing

# %% [markdown]
# # What do you do to check that your code works?
#
# Share your answers on menti.com with code 1872 0008

# %% [markdown]
# By the end of the seminar you should be able to:
#
# - Explain why software testing is important.
# - Distinguish between manual testing and automated testing.
# - Write simple unit tests.
# - Interpret test failures.
# - Appreciate the limitations of testing.

# %% [markdown]
# ## Does this code work?
#
# (Tell your neighbour what you think )

# %%
def area_rectangle(width, height):
    return width * height

# %% [markdown]
# ## "Working" depends on our expected behaviour of our code

# %%
area = area_rectangle(0, 5)
print(area)

area = area_rectangle(-2, 3)
print(area)

area = area_rectangle(2.5, 4)
print(area)
# Out:
# 0
# -6
# 10.0

# %% [markdown]
# By testing systematically:
# - Verifty correctness
# - Make code rubust to software evolution (new features and bug fixes)
# - Enable refactoring by detecting when a modeification unintentionally changes the behaviour of the code

# %% [markdown]
# ## You are already testing your code (manual testing)

# %%
def area_rectangle(width, height):
    return width * height

print(area_rectangle(0, 5))
print(area_rectangle(-2, 3))
print(area_rectangle(2.5, 4))
# Out:
# 0
# -6
# 10.0

# %% [markdown]
# ## Challenges of manual testing
#
# - Relies on the programmer to idenitfy visually when an expectation has not been met
# - Only show the output, and doesn't include what the *expected* output of the code was
# - Program can become cluttered with print statements, especially when testing many cases

# %% [markdown]
# # `assert`
#
# The `assert` statement is used to check that a condition is true during program execution.
#
# If the condition is True, the program continues normally.
#
# If it is False, Python raises an `AssertionError`.

# %%
x = 10
2
assert x > 0

# %%
x = -5
2
assert x > 0
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[9], line 3
#       1 x = -5
#       2 2
# ----> 3 assert x > 0
#
# AssertionError:

# %%
assert area_rectangle(2, 10) == 20

# %%
assert area_rectangle(2, 10) >= 0

# %%
assert area_rectangle(-2, 10) >= 0
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 assert area_rectangle(-2, 10) >= 0
#
# AssertionError:

# %% [markdown]
# We can also provide a custom error message

# %%
area = area_rectangle(-2, 10)

assert area_rectangle(-2, 10) >= 0, f"Expected positive value"
# Out:
# ---------------------------------------------------------------------------
#
# AssertionError                            Traceback (most recent call last)
#
# Cell In[17], line 3
#
#       1 area = area_rectangle(-2, 10)
#
#       2
#
# ----> 3 assert area == 20, f"Expected 20 got {area}"
#
#
#
# AssertionError: Expected 20 got -20

# %%
area = area_rectangle(-2, 10)

assert area == 20, f"Expected 20 got {area}"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[18], line 3
#       1 area = area_rectangle(-2, 10)
#       2
# ----> 3 assert area == 20, f"Expected 20 got {area}"
#
# AssertionError: Expected 20 got -20

# %% [markdown]
# ## Test functions
#
# To organise our code more cleanly, we can write test functions
#
# (these can later be organised as separate files)

# %%
def add(a, b):
    return a + b

def divide(a, b):
    return a / b

def test_add():
    assert add(2, 3) == 5, f'Expected 5, got {add(2, 3)}'

test_add()

# %% [markdown]
# ## How should we test for division by zero?

# %%
def divide(a, b):
    return a / b

# %% [markdown]
# # Choosing test cases
#
# A good test suite includes...
#
# __Representative__ (typical) inputs
# ```python
# area_rectangle(5, 10)
# area_rectangle(2, 3)
# ```
#
# <br>
#
# __Edge case__ inputs
# ```python
# area_rectangle(0, 10)                # boundary value
# area_rectangle(1, 1)                 # smallest positive dimensions
# area_rectangle(-2, 10)               # invalid input
# area_rectangle(1_000_000, 1_000_000) # very large values
# ```

# %% [markdown]
# # Activity
# Write some tests to check if this code works, then fix the function when you identify a problem
#
# Have your tests covered both representative and edge cases?

# %%
def maximum(values):

    "Ruturns the largest in a series of values entered as a list"

    largest = 0

    for value in values:
        if value > largest:
            largest = value

    return largest

# %% [markdown]
# # Writing good tests

# %% [markdown]
# ## 1. Test one thing at a time
# Avoid testing multiple unrelated behaviors in one test.
#
# ## 2. Use descriptive test names

# %%
def test_rectangle_area_is_positive():
    assert area_rectangle(-5, 10) == 50

# %% [markdown]
# ## 3. Structure tests consistently
#
#
# __Arrange__: What input was used?
#
# __Act__: What is being tested?
#
# __Assert__: What result was expected?

# %%
def test_rectangle_area():
    # Arrange
    width = 5
    height = 10

    # Act
    area = area_rectangle(width, height)

    # Assert
    assert area == 50

# %% [markdown]
# ## 4. Test both representative and edge cases
#
# What inputs might a real user provide, and what should happen?

# %%
assert area_rectangle(1, 1) == 1
assert area_rectangle(0, 10) == 0

# %% [markdown]
# ## 5. Make assertions as specific as possible

# %%
# More useful
assert area_rectangle(5, 10) == 50

# Less useful
assert area_rectangle(5, 10) > 0

# %% [markdown]
# ## 6. Include descriptive failure messages

# %%
area = area_rectangle(5, 10)
assert area == 50, f"Expected 50, got {area}"
